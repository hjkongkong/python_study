# %% [markdown]
# # 무신사 티셔츠 스크레이핑
# * [ ] 썸네일 사진 - 001001-상품번호-thumb.jpg
# * [ ] 브랜드
# * [ ] 제품명
# * [ ] 가격(할인 된 상태의 가격)
# * [ ] 제품 만족도
# * [ ] 제품 상세 사진 - 001001-상품번호-detail-(n).jpg

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen, urlretrieve # urlretrieve : 이미지 다운

url = 'https://store.musinsa.com/app/items/lists/001001'

# %%
page =  urlopen(url)
soup = BeautifulSoup(page,'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <!-- Google Tag Manager -->
# <script>
# var selfCertEnabled = "" || "Y";
# var dataLayer = window.dataLayer || [];
# window.addEventListener("load", function() {
#
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#             new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-TXDSFSF');
# }, false);
# </script>
# <!-- End Google Tag Manager -->
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="/favicon.ico?20200213" rel="shortcut icon" type="image/x-icon"/>
# <meta content="총 1896 개 브랜드와  반팔 티셔츠(48920) 긴팔 티셔츠(9453) 민소매 티셔츠(2761) 셔츠/블라우스(16796) 피케/카라 티셔츠(2619) 맨투맨/스웨트셔츠(16400) 후드 티셔츠(11550) 니트/스웨터(5412) 기타 상의(570)" name="description">
# <!-- 페이스북 오픈 그래프 메타태그  -->
# <meta content="648837775133366" id="fbAddId" property="fb:app_id">
# <meta content="website" id="fbOgType" property="og:type"/>
# <meta content="상의(Top) - 반팔 티셔츠 | 무신사 스토어" id="fbOgTitle" property="og:title"/>
# <meta content="https://image.msscdn.net/mfile_s01/fb/share_musinsa.png" id="fbOgImage" property="og:image"/>
# <meta content="총 1896 개 브랜드와  반팔 티셔츠(48920) 긴팔 티셔츠(9453) 민소매 티셔츠(2761) 셔츠/블라우스(16796) 피케/카라 티셔츠(2619) 맨투맨/스웨트셔츠(16400) 후드 티셔츠(11550) 니트/스웨터(5412) 기타 상의(570)" id="fbOgDescription" property="og:description"/>
# <meta content="https://store.musinsa.com/app/items/lists/001001" id="fbOgUrl" property="og:url"/>
# <!--// 페이스북 오픈 그래프 메타태그 -->
# <title>상의(Top) - 반팔 티셔츠 | 무신사 스토어</title>
# <link href="//static.msscdn.net/skin/musinsa/css/magazine_common.css?202007151827" rel="stylesheet" type="text/css">
# <link href="//static.msscdn.net/skin/musinsa/css/store_common.css?202007151824" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/skin/musinsa/css/layout.min.css?202007151722" rel="stylesheet" type="text/css"/>
# <link href="//image.msscdn.net/ui/musinsa/resources/common/css/icon.min.css?202007131522" rel="stylesheet"/>
# <link href="//static.msscdn.net/skin/musinsa/css/guide.min.css?202006221035" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/skin/musinsa/css/style.min.css?2020062914" rel="stylesheet" type="text/css"/><link href="//static.msscdn.net/skin/musinsa/css/sub.css?202007151850" rel="stylesheet" type="text/css">
# <link href="//static.msscdn.net/skin/musinsa/css/media_query.css?20200414" rel="stylesheet" type="text/css">
# <!--<link rel="stylesheet" type="text/css" href="//static.msscdn.net/skin/musinsa/css/font.css?20170221" />-->
# <link href="//static.msscdn.net/skin/musinsa/css/new.css?202007151720" rel="stylesheet" type="text/css">
# <!-- Swiper -->
# <link href="//static.msscdn.net/swiper/swiper.min.css" rel="stylesheet" type="text/css">
# <script src="//static.msscdn.net/swiper/swiper.min.js?20200316"></script>
# <!-- 스토어, 매거진 공통 스크립트 -->
# <script src="//static.msscdn.net/mfile_outsrc/js/vendor/jquery-1.11.1.min.js?20160201" type="text/javascript"></script>
# <script src="//static.msscdn.net/mfile_outsrc/js/common/base.js?20160201" type="text/javascript"></script>
# <script src="//static.msscdn.net/mfile_outsrc/js/common/common.js?2020060501" type="text/javascript"></script>
# <script src="//static.msscdn.net/mfile_outsrc/js/vendor/jquery.easing.js?20160201" type="text/javascript"></script>
# <!--// 스토어, 매거진 공통 스크립트 -->
# <script src="//static.msscdn.net/skin/musinsa/js/mini_cart.js?202007071500" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/common.js?20200630170000" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/jquery.cycle.all.js?20160202" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/m_js/jquery-ui.min.js?20160202" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/jslib.js?20200601" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/jquery.bxslider.js?20180503" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/suggestions.js?202007081457" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/clipboard.min.js?20170406" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/ui.js?20200521" type="text/javascript"></script>
# <!--jqModal-->
# <link href="//static.msscdn.net/skin/musinsa/css/jqModal.css?20160119" rel="stylesheet" type="text/css"/>
# <script src="//static.msscdn.net/skin/musinsa/js/jqModal.min.js?20160511" type="text/javascript"></script>
# <!--//jqModal-->
# <!-- 매거진 관심브랜드 관련 스크립트 -->
# <script src="https://www.musinsa.com/layouts/community/js/ex.script.js" type="text/javascript"></script>
# <!--// 매거진 관심브랜드 관련 스크립트 -->
# <!-- 유사 이미지 상품 검색 -->
# <link href="//static.msscdn.net/skin/musinsa/css/image_search.css?20181203_02" rel="stylesheet" type="text/css"/>
# <script src="//static.msscdn.net/skin/musinsa/js/image_search.js?20200221" type="text/javascript"></script>
# <!-- //유사 이미지 상품 검색 -->
# <script type="text/javascript">
#     if (!String.prototype.startsWith) {
#         String.prototype.startsWith = function(search, pos) {
#             return this.substr(!pos || pos < 0 ? 0 : +pos, search.length) === search;
#         };
#     }
#
#     var pathname = location.pathname;
#     var validStartsWithUris = [
#         '/app/cart',
#         '/app/order',
#         '/app/product/detail'
#     ];
#
#     if (validStartsWithUris.some(function (uri) {
#         return pathname.startsWith(uri);
#     })) {
#         var sdkInstance = "appInsightsSDK";
#         window[sdkInstance] = "appInsights";
#         var aiName = window[sdkInstance], aisdk = window[aiName] || function (e) {
#             function n(e) {
#                 t[e] = function () {
#                     var n = arguments;
#                     t.queue.push(function () {
#                         t[e].apply(t, n)
#                     })
#                 }
#             }
#
#             var t = {config: e};
#             t.initialize = !0;
#             var i = document, a = window;
#             setTimeout(function () {
#                 var n = i.createElement("script");
#                 n.src = e.url || "https://az416426.vo.msecnd.net/scripts/b/ai.2.min.js", i.getElementsByTagName("script")[0].parentNode.appendChild(n)
#             });
#             try {
#                 t.cookie = i.cookie
#             } catch (e) {
#             }
#             t.queue = [], t.version = 2;
#             for (var r = ["Exception"]; r.length;) n("track" + r.pop());
#             if (n("setAuthenticatedUserContext"), n("clearAuthenticatedUserContext"), n("flush"), t.SeverityLevel = {
#                 Verbose: 0,
#                 Information: 1,
#                 Warning: 2,
#                 Error: 3,
#                 Critical: 4
#             }, !(!0 === e.disableExceptionTracking || e.extensionConfig && e.extensionConfig.ApplicationInsightsAnalytics && !0 === e.extensionConfig.ApplicationInsightsAnalytics.disableExceptionTracking)) {
#                 n("_" + (r = "onerror"));
#                 var o = a[r];
#                 a[r] = function (e, n, i, a, s) {
#                     var c = o && o(e, n, i, a, s);
#                     return !0 !== c && t["_" + r]({message: e, url: n, lineNumber: i, columnNumber: a, error: s}), c
#                 }, e.autoExceptionInstrumented = !0
#             }
#             return t
#         }(
#             {
#                 instrumentationKey: '69ce0c4f-f7d1-4bdc-901b-9aa1c2b1e74a',
#                 disableAjaxTracking: true,
#                 correlationHeaderExcludedDomains: ['*.hotjar.io', '*.hotjar.com', '*.google-analytics.com', '*.googletagmanager.com'],
#                 accountId: '' || getCookie('_ga').split('.').splice(-2).join('.')
#             }
#         );
#         window[aiName] = aisdk;
#
#     }
# </script>
# <script type="text/javascript">
# 	var dataLayer = window.dataLayer || [];
# 	dataLayer.push({
# 		"productList" : {
# 			"email": "",
# 			"header_sex": "",
# 			"list" : [
#                                                                             "1517122-0"
#                                                         ,                    "1517111-0"
#                                                         ,                    "1517103-0"
#
#             ]
# 		}
# 	});
# </script>
# <script src="//static.msscdn.net/skin/musinsa/js/jquery.lazyload.min.js?20160119" type="text/javascript"></script>
# <script type="text/javascript">
# var curating_page = 2;
# var curating_cnt = "6";
# var g_tag = "";
#
# $(function() {
# 	$("img.lazyload").lazyload({
# 	});
# });
#
# $(document).ready(function() {
# 	$('#toolTip a.color_list').mouseover(function() {
# 		$(this).prev().show();
# 	}).mouseout(function(){
# 		$(this).prev().hide();
# 	});
#
# 	// 큐레이팅 여부에 따라 상품 리스트 media query 변경
# 	if(curating_cnt > 0) {
# 		var list_kind = $("[name='list_kind']").val();
# 		if(list_kind == "big") {
# 			$("#searchList").removeClass("goods_big_media6").addClass("goods_big_media5");
# 		} else {
# 			$("#searchList").removeClass("goods_small_media10").addClass("goods_small_media8");
# 		}
# 	}
#
# 	$('#top_time_sale').cycle({
# 		fx : 'none',
# 		speed : 500,
# 		timeout: 0,
# 		next : '#top_time_sale_next',
# 		prev : '#top_time_sale_prev'
# 	});
#
#
# 	$('#top_exclusive').cycle({
# 		fx : 'none',
# 		speed : 500,
# 		timeout: 0,
# 		next : '#top_exclusive_next',
# 		prev : '#top_exclusive_prev'
# 	});
#
#
# 	$('#standards_list').cycle({
# 		fx : 'none',
# 		speed : 500,
# 		timeout: 0,
# 		next : '#standards_list_next',
# 		prev : '#standards_list_prev'
# 	});
# });
#
# function priceResult() {
#
# 	var f1 = document.f1;
#
# 	if (isNaN(f1.price1.value) || isNaN(f1.price2.value)) {
# 		alert("숫자를 입력하여 주십시오.");
# 		return false;
# 	}
# 	if (f1.price1.value == "" && f1.price2.value == "") {
# 		return false;
# 	}
# 	if (Number(f1.price1.value) > Number(f1.price2.value) && f1.price2.value != "") {
#
# 		var price = f1.price2.value + "^" + f1.price1.value;
# 		var rr = f1.price1.value;
# 		f1.price1.value = f1.price2.value;
# 		f1.price2.value = rr;
#
# 	} else {
#
# 		var price = f1.price1.value + "^" + f1.price2.value;
#
# 	}
# 	f1.price.value = price;
# 	f1.page.value = 1;
#
# 	f1.submit();
# }
#
# function GetMoreCurating() {
# 	var ff = document.f1;
# 	var u_cat_cd = ff.d_cat_cd.value;
# 	var $container = $('#productBox');
#
# 	$.ajax({
# 		type: "POST",
# 		url: "/app/svc/get_item_brand_curating_list",
# 		data: 'page=' + curating_page + '&u_cat_cd=' + u_cat_cd,
# 		success: function(msg) {
# 			if(msg) {
# 				curating_page++;
# 				$("#curating_area").append(msg);
#
# 				var list_cnt_length = $("input[name='curating_list_cnt']").length;
# 				if($("input[name='curating_list_cnt']").eq(list_cnt_length - 1).val() < 5) {
# 					$("#more_btn").css("display", "none");
# 				}
#
# 			} else {
# 				alert("검색결과가 없습니다.");
# 				return false;
# 			}
# 		}
# 	});
# }
#
# $(window).resize(function() {
# 	var width = document.body.clientWidth;
# 	var list_kind = $("[name='list_kind']").val();
#
# 	if(width <= 1470) {
# 		$("#curating").css("display", "none");
#
# 		if(list_kind == "big") {
# 			$("#searchList").removeClass("goods_big_media5").addClass("goods_big_media6");
# 		} else {
# 			$("#searchList").removeClass("goods_small_media8").addClass("goods_small_media10");
# 		}
# 	} else {
# 		$("#curating").css("display", "");
#
# 		if(list_kind == "big") {
# 			$("#searchList").removeClass("goods_big_media6").addClass("goods_big_media5");
# 		} else {
# 			$("#searchList").removeClass("goods_small_media10").addClass("goods_small_media8");
# 		}
# 	}
# });
#
# function countDownTimeSale(goods_no, r) {
# 	r = parseInt(r,10) - 1;
# 	day = Math.floor(r / (3600 * 24)); mod = r % (3600 * 24);
# 	hrs = Math.floor(mod / 3600); mod = mod % 3600;
# 	min = Math.floor(mod / 60);
# 	sec = mod % 60;
# 	hrs = (day * 24) + hrs;
# 	hrs = (hrs > 9) ? hrs.toString() : '0' + hrs.toString();
# 	min = (min > 9) ? min.toString() : '0' + min.toString();
# 	sec = (sec > 9) ? sec.toString() : '0' + sec.toString();
# 	$('#time_sale_'+goods_no).text("TIME SALE " + hrs + ':' + min + ':' + sec);
#
# 	if(r > 0) {
# 		setTimeout(function(){countDownTimeSale(goods_no, r);},1000);
# 	} else {
#
# 	}
# }
#
# function searchMultiBrand(brand, cmd) {
#
# 	var brands = document.f1.brand.value;
# 	var a_brand = brands.split(",");
#
# 	if(cmd == "add") {
# 		if(a_brand.length > 4) {	// 멀티 브랜드 검색은 최대 5개까지만 가능
# 			alert("브랜드 검색은 최대 5개까지만 가능합니다.\n선택한 브랜드를 취소하고 다시 선택해 주세요.");
# 			return false;
# 		}
#
# 		if(brands.indexOf(brand) == "-1") {	// 이미 선택된 브랜드가 아닐 경우만 추가
# 			brands += (brands == "") ? brand : "," + brand;
# 		}
# 	} else if(cmd == "del") {
# 		brands = "";
# 		for(var i=0; i<a_brand.length; i++) {
# 			if(a_brand[i] != brand) {
# 				brands += (brands == "") ? a_brand[i] : "," + a_brand[i];
# 			}
# 		}
# 	}
# 	//alert(brands);
# 	//document.f1.brand.value = brands;
# 	getGoodsList(document.f1, document.f1.brand, brands, 'Y');
# }
#
# function addTag(tags) {
# 	var f1 = document.f1;
# 	if(g_tag != tags){
# 		location.href="/app/items/lists/"+f1.d_cat_cd.value+"/?tag="+tags;
# 	}else{
# 		location.href="/app/items/lists/"+f1.d_cat_cd.value;
# 	}
# }
#
# function chk_login(){
# 	if ( confirm("회원전용입니다.\n\n로그인 하시겠습니까?") ) {
# 		document.location.href = 'https://www.musinsa.com/?mod=login';
# 	} else {
# 		return false;
# 	}
# }
#
# function chkBlf(value){
#
# 	if(document.f1.blf_chk.checked) {
# 		document.f1.blf_yn.value = value;
# 	} else {
# 		document.f1.blf_yn.value = "";
# 	}
#
# 	document.f1.submit();
# }
#
# function chkBwith(value){
#     document.f1.bwith_yn.value = value;
#     document.f1.submit();
# }
#
#
# function chkCampaign(value) {
#     document.f1.campaign_yn.value = value;
#     document.f1.submit();
# }
#
# function tabGoodsRank(range) {
# 	$('#goods_rank_tab > li').removeClass('selected');
# 	$('#goods_rank_tab_' + range).addClass('selected');
#
# 	var params = {
# 		d_cat_cd: document.f1.d_cat_cd.value,
# 		range: range
# 	};
# 	$('#bestranking_top').load('/app/api/items/get_goods_rank_list', params);
# }
# </script>
# </link></link></link></link></link></meta></meta></head>
# <body>
# <!-- 팝업 공지사항 -->
# <!-- 상단 콘텐츠 영역 -->
# <div class="extend_banner" style="text-align:center; ">
# <!-- 확장배너 시작 -->
# <script type="text/javascript">
# $(function() {
# 	// 처음 방문여부 확인
# 	setCookie("musinsa_store_pc", "1", 7);
# });
# </script>
# <!-- 확장 배너 이미지 -->
# <div class="banner_headTop" style="display:none;">
# <div style="background-color:#e8ebd9"><img alt="무신사 파르티멘토 쇼케이스" class="exImage" src="//image.musinsa.com/images/banner/2020071410225100000076725.jpg"/></div>
# <span class="btn_banner_close">
# <a href="javascript:void(0)" onclick="banner_close(); return false;"><img alt="배너 닫기" src="//image.msscdn.net/skin/musinsa/images/top_banner_close.png"/></a>
# </span>
# </div>
# <div class="banner_headTop_content" style="">
# <!--#27192<span class="headTop-title">16MAIN_UP_1_2_메인 외_파르티멘토 쇼케이스</span>-->
# <span class="headTop-btn-close">X</span>
# <a href="https://www.musinsa.com/?m=magazine&amp;uid=15015&amp;mode=showcase" target="" title="16MAIN_UP_1_2_메인 외_파르티멘토 쇼케이스"><div style="background-color:#e8ebd9"><img alt="무신사 파르티멘토 쇼케이스" class="exImage" src="//image.musinsa.com/images/banner/2020071315483500000071297.jpg"/></div></a> </div>
# <script type="text/javascript">
# 	$(document).on("click",".banner_headTop,.headTop-btn-close",function(){
# 		/* 배너영역 토글 */
#
# 	var $this = $(this);
# 	var $extend_banner = $this.parents(".extend_banner").eq(0);
# 	var $headTopContent = $extend_banner.find(".banner_headTop_content").eq(0);
# 	var $headTop = $extend_banner.find(".banner_headTop").eq(0);
#
# 	$headTopContent.toggle(0);
# 	if($headTop.hasClass('openContents')) {
# 		$headTop.removeClass('openContents');
# 		$headTop.toggle(0);
# 	} else {
# 		$headTop.addClass('openContents');
# 		$headTop.toggle(0);
# 	}
#
# });
# /* 매거진 코어 */
# /*쿠키세팅*/
# function setCookie(name,value,expiredays)
# {
# 	var todayDate = new Date();
# 	todayDate.setDate( todayDate.getDate() + expiredays );
# 	document.cookie = name + "=" + escape( value ) + "; path=/; expires=" + todayDate.toGMTString() + "; domain=.musinsa.com;"
# }
# /*쿠키추출*/
# function getCookie( name )
# {
# 	var nameOfCookie = name + "=";
# 	var x = 0;
# 	while ( x <= document.cookie.length )
# 	{
# 		var y = (x+nameOfCookie.length);
# 		if ( document.cookie.substring( x, y ) == nameOfCookie )
# 		{
# 			if ( (endOfCookie=document.cookie.indexOf( ";", y )) == -1 ) endOfCookie = document.cookie.length;
# 			return unescape( document.cookie.substring( y, endOfCookie ) );
# 		}
# 		x = document.cookie.indexOf( " ", x ) + 1;
# 		if ( x == 0 ) break;
# 	}
# 	return "";
# }
# var setBrowserData = function(key,val)
# {
# 	if((navigator.userAgent.match(/iPhone/i)) || (navigator.userAgent.match(/iPod/i))) {
# 		return setCookie(key,val,30);
# 	}
# 	var storage =  window.localStorage;
# 	if(storage)
# 	{
# 		return storage.setItem(key,val);
# 	}
# 	else
# 	{
# 		return setCookie(key,val,30);
# 	}
# }
#
# var getBrowserData = function(key)
# {
# 	if((navigator.userAgent.match(/iPhone/i)) || (navigator.userAgent.match(/iPod/i))) {
# 		return getCookie(key);
# 	}
# 	var storage = window.localStorage;
# 	if(storage)
# 	{
# 		return storage.getItem(key);
# 	}
# 	else
# 	{
# 		return getCookie(key);
# 	}
# }
# function banner_close() {
# 	$('.extend_banner').hide();
# 	setCookie("musinsa_banner_close", "1", 1);
#
# }
#
# </script>
# <!-- 확장배너 종료 -->
# </div>
# <script type="text/javascript">
# $(function() {
# 	var special_top_open_yn = getCookie("special_top_open_yn");
# 	var musinsa_banner_close = getCookie("musinsa_banner_close");
#
# 	if ( special_top_open_yn == 'Y' ) {
# 		if( musinsa_banner_close != "1") {
# 			$('.extend_banner').show();
# 		}
# 	}
#
# 	if(getCookie("tvcf_close") != "done"){
# 		$('#tvcf_close').show();
# 	}
# });
# </script>
# <!--
# <div class="bear_banner" style="">
# 	<a href="/app/outer_festival" class="img_banner"><img src="//image.msscdn.net/skin/musinsa/images/bear.png" alt="곰돌이배너" /></a>
# 	<a href="javascript:void(0)" onclick="bear_close(); return false;" class="btn_banner"><img src="//image.msscdn.net/skin/musinsa/images/bear_btn.png" alt="곰돌이배너닫기" /></a>
# </div>
#
# <script type="text/javascript">
# function bear_close() {
# 	$('.bear_banner').hide();
# 	setCookie("bear_banner_close", "1", 1);
# }
#
# </script>
#
#
# -->
# <!-- 상단 배너 -->
# <!-- 임시 주석 처리
# <div class="top_banner"><img src="//image.msscdn.net/skin/musinsa/images/banner_top.jpg" width="1167" height="50" border="0" alt=""></div>
# --><!-- //상단 배너 -->
# <script type="text/javascript">
# var left_menu_open_yn = "";
# var special_top_open_yn = "";
#
# $(document).ready(function() {
# 	// 바로접속 레이어
# 	$('.atonce').mouseover(function() {
# 		$(this).children('#atLayer').css('display','block');
# 		}).mouseout(function() {
# 		$(this).children('#atLayer').css('display','none');
# 	});
#
# 	// 인기검색어, 추천검색어 스크롤 버튼
# 	$(document).on("click",".btnH",function() {
# 		$('.keywordH').toggleClass('step2_on');
# 	});
# 	$(document).on("click",".btnR",function() {
# 		$('.keywordR').toggleClass('step2_on');
# 	});
#
# 	// 인기검색어 슬라이드
# 	$("#hotkeyword").bxSlider({
# 		auto : true,
# 		pager : false,
# 		controls : false,
# 		speed : 700,
# 		mode : "vertical"
# 	});
#
# 	// 인기 검색어 mouseenter
# 	$('#hotkeyword').mouseenter(function() {
# 		if($('#recommend_kwd').css('display') == 'none'){
# 			if(($("#search_kwd div").length == 0)){
# 				search_kwd();
# 			}
# 			$('.layer-keyword-top').css("display","block");
# 		}
# 	});
#
# 	// 인기 검색어 mouseleave
# 	$('.layer-keyword-top').mouseleave(function() {
# 		$('.layer-keyword-top').css("display","none");
# 	});
#
# 	$(".urlCopy-btn .url").click(function() {
# 		if(click_flag) {
# 			click_flag = false;
# 		}
#
# 		if(!Clipboard.isSupported()) {
# 			alert("복사를 지원하지 않습니다");
# 			return false;
# 		}
# 	});
#
# 	//최근검색어 레이어 노출
# 	$('#search_query').click(function() {
# 		if($('#recommend_kwd').css('display') == 'none'){
# 			if($('.layer-keyword-top').css("display") == "none"){
# 				if(($("#search_kwd div").length == 0)){
# 					search_kwd();
# 				}
# 				$('.layer-keyword-top').toggle();
# 			}
# 		}
# 	});
# });
#
# // 로그인 창 토글
# var socialFuctOpenLogin = function() {
# 	var $onoffobj = $('span[loginOnOff=1]');
# 	var $openEl = $('div.open_login');
# 	var _onoff_status = $onoffobj.html();
# 	var _on = $onoffobj.attr('on');
# 	var _off = $onoffobj.attr('off');
# 	if(_onoff_status == _off) {
# 		//닫혀있을 경우
# 		$onoffobj.html(_on);
# 		$openEl.animate({height:203},300);
# 	}else {
# 		//열려있을 경우
# 		$onoffobj.html(_off);
# 		$openEl.animate({height:1},300);
# 	}
# }
#
# // 검색
# function SearchKwd() {
# 	var ff = document.getElementById("search_form");
# 	var kwd_type = Suggestions.kwd_type;
# 	var kwd = ff.q.value;
# 	if(kwd_type == "url") {
# 		document.location.href = Suggestions.kwd_value;
# 		return false;
# 	} else {
# 		if ( kwd == "" ) {
# 			if(ff.q.value == "" || ff.q.value == "검색단어입력") {
# 				alert("검색어를 입력하세요.");
# 				ff.q.focus();
# 				return false;
# 			}
# 		} else {
# 			ff.q.value = kwd;
# 		}
# 	}
#
# 	dataLayer.push({'layerCategory': '검색','layerAction':'입력_직접입력','layerLabel': '','event' : 'ga_event','nonInteraction' : false});
# 	ff.submit();
# 	return true;
# }
#
# function upKwd(kwd){
# 	$(".head-search-inp").val(kwd);
# }
#
# function closeLayer(obj){
#
# 	$('.layer-keyword-top').css('display','none');
# 	//$('#recommend_kwd').css('display','block');
# 	if(obj.length == 0){
# 		$('.layer-keyword-top').toggle();
# 		$('#recommend_kwd').toggle();
# 	}
# }
#
# function delSearch(obj,kwd,key){
# 	$.ajax({
# 		type: "GET",
# 		url: "/app/searches/recent_keyword_delete/" + key + "/?keyword=" + encodeURIComponent(kwd),
# 		success: function(msg){
# 			if(msg == "1"){
# 				$("#recent_kwd ul li").remove();
# 			}else if(msg == "2"){
# 				$(obj).parent().parent().remove();
# 			}
# 		}
# 	});
# }
#
# // 검색창 검색어 레이아웃
# function search_kwd(){
# 	$.ajax({
# 		type: "POST",
# 		url: "/app/svc/search_kwd",
# 		success: function(msg) {
# 			$("#search_kwd").html(msg);
# 		}
# 	});
# }
#
# </script>
# <div class="top-column column top-musinsa">
# <!--헤더 header start-->
# <div class="header store_header clearfix" id="default_top">
# <div class="main-wrapper wrapper">
# <h1 class="title"><a href="/">MUSINSA</a></h1>
# <div class="search-wrapper wrapper clearfix">
# <!--검색창-->
# <div class="fl searchInput-box box">
# <form action="/app/product/search" id="search_form" method="get" onsubmit="return SearchKwd();">
# <input id="search_type" name="type" type="hidden" value=""/>
# <input name="keyword_value" type="hidden" value=""/>
# <input name="keyword_url" type="hidden" value=""/>
# <input autocomplete="off" class="search head-search-inp" id="search_query" maxlength="30" name="q" onkeydown="Suggestions.Go();" onkeyup="closeLayer(this.value); Suggestions.Do(this.value,'search_layer','suggest_keyword','suggest_brand','suggest_items','suggest_goods');" type="text">
# <span class="search-btn btn ui-head-search-btn" onclick="$('#search_form').submit();"><i class="ic-22-stencil-search ic-white">검색</i></span>
# <!-- [D] 이미지 검색 버튼 -->
# <span class="cam-btn btn ui-head-search-btn" onclick="dataLayer.push({'layerCategory': '검색','layerAction':'이미지검색','layerLabel': '','event' : 'ga_event','nonInteraction' : false});"><i class="ic-22-stencil-camera">이미지 검색</i></span>
# </input></form>
# </div>
# <!--//검색창-->
# <!--검색어 랭킹-->
# <div class="popularSearchWord-ranking-list-wrapper">
# <!--롤링 랭킹-->
# <div class="rollingRanking">
# <dl class="bxSlider" id="hotkeyword">
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">1등 : </span>
# <span class="word">반팔</span>
# <span class="rank-variation-even rank-variation"><em class="even">-</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">2등 : </span>
# <span class="word">디스이즈네버댓</span>
# <span class="rank-variation-even rank-variation"><em class="even">-</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">3등 : </span>
# <span class="word">라퍼지스토어 조거</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-down">▼ 1</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">4등 : </span>
# <span class="word">남자 반바지</span>
# <span class="rank-variation-even rank-variation"><em class="even">-</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">5등 : </span>
# <span class="word">트레이닝세트</span>
# <span class="rank-variation-even rank-variation"><em class="even">-</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">6등 : </span>
# <span class="word">lmc</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-down">▼ 1</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">7등 : </span>
# <span class="word">트레이닝 반바지</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-down">▼ 1</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">8등 : </span>
# <span class="word">루즈핏 반팔티</span>
# <span class="rank-variation-even rank-variation"><em class="even">-</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">9등 : </span>
# <span class="word">무신사 스탠다드 밸브 마스크 kf 94</span>
# <span class="rank-variation-even rank-variation"><em class="even">-</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">10등 : </span>
# <span class="word">라퍼지스토어 셋업</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-up">▲ 96</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">11등 : </span>
# <span class="word">타이다이</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-down">▼ 1</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">12등 : </span>
# <span class="word">래플</span>
# <span class="rank-variation-even rank-variation"><em class="even">-</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">13등 : </span>
# <span class="word">나이키</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-down">▼ 3</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">14등 : </span>
# <span class="word">커버낫</span>
# <span class="rank-variation-even rank-variation"><em class="even">-</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">15등 : </span>
# <span class="word">페이즐리</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-up">▲ 82</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">16등 : </span>
# <span class="word">무신사 스탠다드</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-down">▼ 12</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">17등 : </span>
# <span class="word">카고조거팬츠</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-up">▲ 123</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">18등 : </span>
# <span class="word">폴로</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-up">▲ 1</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">19등 : </span>
# <span class="word">컨버스</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-down">▼ 1</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">20등 : </span>
# <span class="word">반바지</span>
# <span class="rank-variation-even rank-variation"><em class="even">-</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">21등 : </span>
# <span class="word">앤더슨벨</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-up">▲ 1</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">22등 : </span>
# <span class="word">후드집업</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-up">▲ 31</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">23등 : </span>
# <span class="word">백팩</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-up">▲ 2</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">24등 : </span>
# <span class="word">우포스</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-down">▼ 9</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">25등 : </span>
# <span class="word">아디다스</span>
# <span class="rank-variation-even rank-variation"><em class="even">-</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">26등 : </span>
# <span class="word">바람막이</span>
# <span class="rank-variation-even rank-variation"><em class="even">-</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">27등 : </span>
# <span class="word">반스</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-down">▼ 5</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">28등 : </span>
# <span class="word">샌들</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-up">▲ 19</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">29등 : </span>
# <span class="word">마크곤잘레스</span>
# <span class="rank-variation-even rank-variation"><em class="even">-</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">30등 : </span>
# <span class="word">칼하트</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-down">▼ 3</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">31등 : </span>
# <span class="word">후드티</span>
# <span class="rank-variation-even rank-variation"><em class="even">-</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">32등 : </span>
# <span class="word">셔츠</span>
# <span class="rank-variation-even rank-variation"><em class="even">-</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">33등 : </span>
# <span class="word">트레이닝바지</span>
# <span class="rank-variation-even rank-variation"><em class="even">-</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">34등 : </span>
# <span class="word">조거팬츠</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-up">▲ 5</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">35등 : </span>
# <span class="word">슬리퍼</span>
# <span class="rank-variation-even rank-variation"><em class="even">-</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">36등 : </span>
# <span class="word">반팔티</span>
# <span class="rank-variation-even rank-variation"><em class="even">-</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">37등 : </span>
# <span class="word">유니폼브릿지</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-down">▼ 28</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">38등 : </span>
# <span class="word">가방</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-down">▼ 2</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">39등 : </span>
# <span class="word">페이탈리즘</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-down">▼ 25</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">40등 : </span>
# <span class="word">맨투맨</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-down">▼ 2</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">41등 : </span>
# <span class="word">에코백</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-up">▲ 8</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">42등 : </span>
# <span class="word">와이드팬츠</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-down">▼ 16</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">43등 : </span>
# <span class="word">린넨 셔츠</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-down">▼ 22</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">44등 : </span>
# <span class="word">오버핏 반팔</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-down">▼ 2</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">45등 : </span>
# <span class="word">뉴발란스</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-up">▲ 1</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">46등 : </span>
# <span class="word">모자</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-down">▼ 5</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">47등 : </span>
# <span class="word">양말</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-up">▲ 3</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">48등 : </span>
# <span class="word">지갑</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-up">▲ 10</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">49등 : </span>
# <span class="word">버킷햇</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-up">▲ 27</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">50등 : </span>
# <span class="word">이지부스트</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-up">▲ 10</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">51등 : </span>
# <span class="word">스컬프터</span>
# <span class="rank-variation-even rank-variation"><em class="even">-</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">52등 : </span>
# <span class="word">쿠어</span>
# <span class="rank-variation-even rank-variation"><em class="even">-</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">53등 : </span>
# <span class="word">뮬</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-up">▲ 13</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">54등 : </span>
# <span class="word">쿠어반팔</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-down">▼ 6</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">55등 : </span>
# <span class="word">로맨틱 크라운</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-up">▲ 29</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">56등 : </span>
# <span class="word">슬랙스</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-down">▼ 25</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">57등 : </span>
# <span class="word">모드나인</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-down">▼ 37</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">58등 : </span>
# <span class="word">미나브</span>
# <span class="rank-variation-even rank-variation"><em class="even">-</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">59등 : </span>
# <span class="word">비바스튜디오</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-up">▲ 4</em></span>
# </a>
# </dd>
# <dd class="listItem">
# <a href="javascript:void(0)">
# <span class="rank">60등 : </span>
# <span class="word">쪼리</span>
# <span class="rank-variation-even rank-variation"><em class="rank-variation-up">▲ 19</em></span>
# </a>
# </dd>
# </dl>
# </div>
# <!--//롤링 랭킹-->
# <!--랭킹 팝업 : 개선 후 삭제-->
# <!--//랭킹 팝업 : 개선 후 삭제-->
# </div>
# <!--//검색어 랭킹-->
# </div>
# <!--오른쪽 상단 메뉴-->
# <div class="gnb wrapper clearfix">
# <ul class="gnb-list clearfix gnb-list-wrap">
# <li class="hovering gnb-ranking-list">
# <a href="/app/contents/bestranking">랭킹</a>
# <ul class="hoverTarget">
# <li><a href="/app/contents/bestranking"><span>상품</span></a></li>
# <li><a href="/app/usr/brand_rank"><span>브랜드</span></a></li>
# <li><a href="/app/usr/search_ranking"><span>검색어</span></a></li>
# </ul>
# </li>
# <li class="hovering gnb-update-list">
# <a href="/app/news/lists">업데이트</a>
# <ul class="hoverTarget">
# <li><a href="/app/news/lists"><span>전체</span></a></li>
# <li><a href="/app/news/lists?type=2"><span>신상품</span></a></li>
# <li><a href="/app/news/lists?type=4"><span>세일</span></a></li>
# <li><a href="/app/news/lists?type=8"><span>재입고</span></a></li>
# <li><a href="/app/news/lists?type=16"><span>이벤트</span></a></li>
# <li><a href="/app/news/lists?type=64"><span>입점</span></a></li>
# <li><a href="/app/news/lists?pop=Y"><span>인기</span></a></li>
# <li><a href="/app/event_brand_collection"><span>신규 브랜드</span></a></li>
# </ul>
# </li>
# <li class="hovering">
# <a href="/app/contents/brandshop">브랜드</a>
# <ul class="hoverTarget">
# <li><a href="/app/contents/brandshop"><span>브랜드</span></a></li>
# <li><a href="/app/designer/lists"><span>디자이너</span></a></li>
# <li><a href="/app/shopinshop"><span>숍인숍</span></a></li>
# </ul>
# </li>
# <li class="hovering gnb-style-list">
# <a href="/app/styles/lists">코디</a>
# <ul class="hoverTarget">
# <li><a href="/app/styles/lists"><span>스타일링</span></a></li>
# <li><a href="/app/staff/lists"><span>스태프 스냅</span></a></li>
# <li><a href="/app/street/lists"><span>스트릿 스냅</span></a></li>
# </ul>
# </li>
# <li class="hovering gnb-special">
# <a href="/app/showcase/lists">스페셜</a>
# <ul class="hoverTarget">
# <li><a href="/app/showcase/lists"><span>쇼케이스</span></a></li>
# <li><a href="/app/specialissue/lists"><span>스페셜 이슈</span></a></li>
# <li><a href="/app/exclusive/lists"><span>단독 상품</span></a></li>
# </ul>
# </li>
# <li class="hovering gnb-contents">
# <a href="/app/curating/lists">콘텐츠</a>
# <ul class="hoverTarget">
# <li><a href="/app/curating/lists"><span>큐레이팅</span></a></li>
# <li><a href="/app/video/lists"><span>비디오</span></a></li>
# <li><a href="/app/reviews/lists"><span>회원 후기</span></a></li>
# </ul>
# </li>
# <li class="hovering gnb-onsale">
# <a href="/app/contents/onsale">세일</a>
# <ul class="hoverTarget">
# <li><a href="/app/contents/onsale"><span>세일</span></a></li>
# <li><a href="/app/contents/onsale?sale_yn=Y&amp;sale_dt_yn=Y&amp;chk_timesale=on"><span>타임세일</span></a></li>
# <li class="list_clearance"><a href="/app/clearance/lists"><span>클리어런스</span></a></li>
# <li><a href="/app/plan/lists"><span>기획전</span></a></li>
# <li><a href="/app/contents/coupon_online"><span>쿠폰</span></a></li>
# </ul>
# </li>
# <li class="hovering gnb-event">
# <a href="/app/raffle/lists">이벤트</a>
# <ul class="hoverTarget">
# <li><a href="/app/raffle/lists"><span>래플</span></a></li>
# <li><a href="/app/event_random/lists"><span>랜덤 쿠폰</span></a></li>
# <li><a href="/app/content/s/usr/membership"><span>천원 이벤트</span></a></li>
# <li><a href="https://my.musinsa.com/event/v1/friend"><span>친구 초대</span></a></li> <li><a href="/app/plan/lists?plan_kind=6"><span>체험단</span></a></li>
# <li><a href="/app/specialissue/lists?event_yn=Y&amp;state=30"><span>스페셜 이슈</span></a></li>
# <li><a href="/app/brand_event/lists">신규 브랜드</a></li>
# <li><a href="/app/contents/gift_list">사은품</a></li>
# </ul>
# </li>
# <li class="emphasis-blue hovering magazine">
# <a href="https://www.musinsa.com">매거진</a>
# <ul class="hoverTarget">
# <li><a href="https://www.musinsa.com/?m=news"><span>뉴스</span></a></li>
# <li><a href="https://www.musinsa.com/?m=magazine"><span>매거진</span></a></li>
# <li><a href="https://www.musinsa.com/?m=lookbook"><span>룩북</span></a></li>
# <li><a href="https://www.musinsa.com/?m=street"><span>스트릿 스냅</span></a></li>
# <li><a href="https://www.musinsa.com/?m=gallery"><span>갤러리</span></a></li>
# <li><a href="https://www.musinsa.com/?m=market"><span>중고장터</span></a></li>
# <li><a href="https://www.musinsa.com/?m=forum"><span>커뮤니티</span></a></li>
# </ul>
# </li>
# </ul>
# </div>
# <!--//오른쪽 상단 메뉴-->
# <!-- 통합 검색폼 키워드 입력시 뜨는 추천검색어레이어-->
# <div class="store-searchWord-box searchWord-box box clearfix ui-search-recommend-area ui-search-recommend-area-result search_layer" id="recommend_kwd">
# <div class="left-column column">
# <dl class="recommendSearchWord-list list store_list" id="suggest_keyword" onclick="dataLayer.push({'layerCategory': '검색','layerAction':'입력_추천검색어','layerLabel': '','event' : 'ga_event','nonInteraction' : false});">
# <dt class="title-listItem listItem clearfix">
# <span class="title">추천 검색어</span>
# </dt>
# </dl>
# <dl class="recommendBrand-list list store_list" id="suggest_brand" onclick="dataLayer.push({'layerCategory': '검색','layerAction':'입력_추천브랜드','layerLabel': '','event' : 'ga_event','nonInteraction' : false});">
# <dt class="title-listItem listItem clearfix">
# <span class="title">추천 브랜드</span>
# </dt>
# </dl>
# <dl class="useCategory-list list store_list" id="suggest_items" onclick="dataLayer.push({'layerCategory': '검색','layerAction':'입력_용도카테고리','layerLabel': '','event' : 'ga_event','nonInteraction' : false});">
# <dt class="title-listItem listItem clearfix">
# <span class="title">용도 카테고리</span>
# </dt>
# </dl>
# </div>
# <div class="right-column column">
# <dl class="recommendProduct-list list store_list" onclick="dataLayer.push({'layerCategory': '검색','layerAction':'입력_추천상품','layerLabel': '','event' : 'ga_event','nonInteraction' : false});">
# <dt class="title-listItem listItem clearfix">
# <span class="title">추천 상품</span>
# <span class="closeBtn btn" onclick="Suggestions.Close('search_layer'); return false;">닫기</span>
# </dt>
# <div id="suggest_goods">
# </div>
# </dl>
# </div>
# </div>
# <!-- //통합 검색폼 키워드 입력시 뜨는 추천검색어레이어  : 개선 후 삭제-->
# <div class="store-searchWord-box searchWord-box box clearfix ui-search-recommend-area ui-search-recommend-area-result layer-keyword-top" id="search_kwd"></div>
# </div>
# <!--<div class="layerbanner_repeat outerFsetival"><a href="/app/campaign/main/34">아우터</a></div>-->
# <!-- 성별 선택 부분 -->
# <div class="header_group_area">
# <ul class="group_list">
# <li><a class="selected" href="https://store.musinsa.com/app/items/lists/001001">전체</a></li>
# <!--<li><a href="javascript:void(0)" onclick="setSexKind('2'); return false;">남성</a></li>//-->
# <li><a href="https://wusinsa.musinsa.com/app/items/lists/001001">우신사(여성)</a></li>
# <li><a href="/app/brand/goods_list/musinsastandard">스탠다드</a></li>
# <li><a href="/app/terrace/lists?cate_type=all">테라스샵</a></li>
# <!--<li><a href="javascript:void(0)" onclick="setSexKind('8'); return false;">키즈</a></li>//-->
# <!--<li><a href="javascript:void(0)" onclick="setSexKind('16'); return false;">라이프</a></li>//-->
# </ul>
# <p class="txt-raffle">래플에 참여해 보세요! <a href="/app/raffle/lists">래플 바로가기</a></p>
# </div>
# <!--//성별 선택 부분-->
# <!--유저 로그인 메뉴 start-->
# <div class="userMenu-wrapper toggleBox">
# <ul class="userMenu-list-notLogin userMenu-list">
# <li class="listItem loginBtn" data-for="loginBox">
# <a href="https://my.musinsa.com/login/v1/login?referer=https%3A%2F%2Fstore.musinsa.com%2Fapp%2Fitems%2Flists%2F001001">로그인</a>
# </li>
# <li class="listItem atonce">
# <span class="txt_direct_on">바로접속</span><span class="icon_on box_icon font-mss">ON</span>
# <!-- 바로접속 ON 마우스 오버 시 -->
# <div class="top_on_layer" id="atLayer">
# <div class="on_contents">
# <strong>바로접속</strong> <span class="icon_on box_icon font-mss">ON</span> <strong>고객혜택</strong>
# <ol>
# <li>1. 100% 무료배송</li>
# <li>2. 회원 등급별 추가할인 / 추가 적립금</li>
# <li>3. 사은품 선택 가능</li>
# <li>4. 쿠폰 발급 / 쿠폰 사용 가능</li>
# <li>5. 후기 적립금 제공</li>
# </ol>
# <p><a href="/app/cs/notice_view/172?page=1">바로가기 안내</a></p>
# </div>
# </div>
# <!-- //바로접속 ON 마우스 오버 시 -->
# </li>
# <li class="listItem"><a href="javascript:location.href='https://my.musinsa.com/member/v2/join'" title="회원가입"><span>회원가입</span></a></li>
# <li class="listItem"><a href="javascript:location.href='https://my.musinsa.com/member/v2/search/password'" title="비밀번호찾기"><span>비밀번호찾기</span></a></li>
# <li class="listItem cart_list" id="cart"><!-- activityInfo activity_cart //-->
# <a class="activity_cart_area" href="/app/cart" title="장바구니">장바구니(<span class="cart-count">0</span>)</a>
# <!--2016년 2월 첫주까지 개선할 사항으로 우선은 주석 처리 - conship-->
# <div class="cart_out_line"><a href="/app/cart">장바구니(<span class="cart-count">0</span>)</a></div>
# <ul class="activityInfo-list infoLayout activity_cart_box cart_in_positon" id="mini_cart" style="display:none"></ul>
# </li>
# <li class="listItem"><a href="/app/mypage/order_list_opt">주문배송조회</a></li>
# <li class="listItem"><a href="/app/cs">고객센터</a></li>
# <!-- 신규가입 이벤트 문구 추가 -->
# <li class="listItem top-join-txt"><a href="/app/content/s/usr/membership">회원 가입 EVENT. 신규 가입 시, 15% 쿠폰 + 3,000원 적립금/무신사 스탠다드 990원 구매 기회/본인인증 시, 10% 쿠폰 제공</a></li>
# <!-- //신규가입 이벤트 문구 추가 -->
# </ul>
# </div>
# <!--유저 로그인 메뉴 end-->
# <!-- 이벤트 광고--
#
# <script type="text/javascript">
# $(document).on("click",".p_event_banner_title,.a_event_banner_title",function(){
# 	/* 배너영역 토글 */
# 	$(".event_banner").toggle(0);
# 	if($(".event_banner").hasClass('openContents')) {
# 		$(".event_banner").removeClass('openContents');
# 		$(".a_event_banner_title").html("닫기");
# 		setCookie("musinsa_store_pc", "0", 7);
# 	} else {
# 		$(".event_banner").addClass('openContents');
# 		$(".a_event_banner_title").html("열기");
# 		setCookie("musinsa_store_pc", "1", 7);
# 	}
# });
# </script>
#
# 		<div class="event_banner_title">
# 			<p class="p_event_banner_title">2017 아우터 페스티벌</p>
# 			<a href="javascript:void(0)" class="a_event_banner_title">닫기</a>
# 		</div>
# 		<div class="event_banner " style="background-color:#c1a8a3;">
# 			<div class="inner">
# 				<a href="/app/campaign/main/34"><img src="//image.msscdn.net/skin/musinsa/images/outer_festival/ib_pc.jpg" alt="아우터페스티벌" /></a>
# 			</div>
# 		</div>
# 	<!-- //이벤트 광고-->
# </div>
# <!--헤더 header end-->
# <div class="header header-small store_header clearfix" id="short_top_special" style="display:none">
# <div class="main-wrapper wrapper">
# <h1 class="title"><a href="javascript:void(0)" onclick="showShortTopSpecial(); return false;">MUSINSA STORE 메뉴 열기</a></h1>
# </div>
# </div>
# </div>
# <!--image search layer-->
# <form action="" enctype="multipart/form-data" id="frm_image_search" method="POST" style="display:none;">
# <input id="image_file" name="image_file" type="file"/>
# <input id="submit_image_search" type="submit"/>
# </form>
# <div class="wrap_image_search_form top imageSearch-musinsa" style="display:none">
# <div class="tab_menu">
# <span class="t1 active">이미지 URL 붙여넣기</span>
# <span class="t2">이미지 업로드</span>
# </div>
# <div class="content">
# <div class="c1">
# <input class="image_url" name="image_url" type="text"/>
# <input class="image_url_btn" type="button" value="이미지로 검색"/>
# </div>
# <div class="c2">
# <span class="image_file_btn">파일 선택</span>
# <span class="image_file_text">선택된 파일이 없습니다.</span>
# <input class="image_file" type="file"/>
# </div>
# </div>
# </div>
# <div class="wrap_image_search_form_cover top">여기에 이미지를 드롭하세요.</div>
# <div class="wrap_image_search_form_mask"></div>
# <!--//image search layer-->
# <!--sns share layer-->
# <div class="layer-wrap-share" id="layer_share" style="display:none;">
# <div>
# <a class="btn-close" href="javascript:void(0)" onclick="closeSharePop(); return false;"><img alt="닫기" src="//image.msscdn.net/skin/musinsa/images/btn_x_23.png"/></a>
# <!-- url 복사 -->
# <div class="box-share">
# <div class="urlCopy-btn">
# <input class="plain-btn btn" id="textFooterUrl" type="hidden" value="">
# <span class="plain-btn btn" id="spanFooterUrl" style="width:122px;padding:9px 10px;background:#f3f3f3;color:#b2b2b2;height:14px;font-weight:normal;overflow: hidden;white-space: nowrap;">
# </span><button class="url plain-btn btn" id="btnFooterUrlCopy" type="button">URL복사</button>
# </input></div>
# <p>- 현재 보고 있는 페이지를 공유합니다.</p>
# <div class="share-sns">
# <a href="javascript:void(0)" onclick="commonSnsAction('facebook'); return false;">
# <img alt="페이스북" src="//image.msscdn.net/skin/musinsa/images/icon_facebook_60.png"/>
# <span>페이스북</span>
# </a>
# <a href="javascript:void(0)" onclick="commonSnsAction('twitter'); return false;">
# <img alt="트위터" src="//image.msscdn.net/skin/musinsa/images/icon_twitter_60.png"/>
# <span>트위터</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <script>
#
# 	$(document).ready(function () {
# 		commonSnsAction('clipboard');
# 	});
#
# </script>
# ...
# <a class="paging-btn btn" href="javascript:void(0)" onclick="listSwitchPage(document.f1, '6'); return false;">6</a>
# <a class="paging-btn btn" href="javascript:void(0)" onclick="listSwitchPage(document.f1, '7'); return false;">7</a>
# <a class="paging-btn btn" href="javascript:void(0)" onclick="listSwitchPage(document.f1, '8'); return false;">8</a>
# <a class="paging-btn btn" href="javascript:void(0)" onclick="listSwitchPage(document.f1, '9'); return false;">9</a>
# <a class="paging-btn btn" href="javascript:void(0)" onclick="listSwitchPage(document.f1, '10'); return false;">10</a>
# <a class="fa fa-angle-right paging-btn btn next" href="javascript:void(0)" onclick="listSwitchPage(document.f1, '11');; return false;"></a>
# <a class="fa fa-angle-double-right paging-btn btn last" href="javascript:void(0)" onclick="listSwitchPage(document.f1, '544');; return false;"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- // 상품리스트 -->
# <!-- 쇼핑기획 -->
# <a name="tabanchor"></a>
# <div class="right_contents hover_box">
# <span class="title-box list_tit font-mss">Shopping Topic <span class="korSub">쇼핑 기획</span></span>
# <!-- 기획전 목록 -->
# <ul class="n-list-event list-add">
# <li>
# <a href="/app/plan/views/10466">
# <div class="img">
# <img alt="폴햄 X 세븐브로이 소확행 맥확행 컬렉션" src="//image.musinsa.com/images/plan_w_mobile_img/2020071517492900000016749.jpg"/>
# </div>
# <strong>폴햄 X 세븐브로이 소확행 맥확행 컬렉션</strong>
# <p>폴햄과 세븐브로이의 쿨한 컬래버레이션! 무신사 한정 발매 컬렉션을 만나보세요.</p>
# <span>20.07.16 - 20.07.30</span>
# </a>
# </li>
# <li>
# <a href="/app/plan/views/10617">
# <div class="img">
# <img alt="지이크 X 우루사 컬래버레이션" src="//image.musinsa.com/images/plan_w_mobile_img/2020071610313800000067263.jpg"/>
# </div>
# <strong>지이크 X 우루사 컬래버레이션</strong>
# <p>지이크와 우루사가 협업한 특별한 컬렉션을 만나볼 수있습니다.</p>
# <span>20.07.16 - 20.07.30</span>
# </a>
# </li>
# <li>
# <a href="/app/plan/views/10616">
# <div class="img">
# <img alt="시디스콤마 특별 기획전" src="//image.musinsa.com/images/plan_w_mobile_img/2020071611575200000035251.jpg"/>
# </div>
# <strong>시디스콤마 특별 기획전</strong>
# <p>시디스콤마 시즌오프 기획전입니다. 브랜드 시디스콤마의 다양한 상품을 단독 최대 80% 할인된 가격으로 만나볼 수 있습니다.</p>
# <span>20.07.16 - 20.07.31</span>
# </a>
# </li>
# <li>
# <a href="/app/plan/views/10420">
# <div class="img">
# <img alt="본챔스 빅세일" src="//image.musinsa.com/images/plan_w_mobile_img/2020070915265900000017142.jpg"/>
# </div>
# <strong>본챔스 빅세일</strong>
# <p>여름 아이템&amp;역시즌 상품을 최대 80% 할인된 가격으로 만나보세요!</p>
# <span>20.07.10 - 20.07.16</span>
# </a>
# </li>
# <li>
# <a href="/app/plan/views/10425">
# <div class="img">
# <img alt="슬로우애시드 빅세일" src="//image.musinsa.com/images/plan_w_mobile_img/2020071018091600000065892.jpg"/>
# </div>
# <strong>슬로우애시드 빅세일</strong>
# <p>슬로우애시드 인기상품을 최대 80% 할인된 가격으로 만나보세요.</p>
# <span>20.07.13 - 20.07.27</span>
# </a>
# </li>
# <li>
# <a href="/app/plan/views/10581">
# <div class="img">
# <img alt="유니폼브릿지 20 S/S 시즌오프" src="//image.musinsa.com/images/plan_w_mobile_img/2020071609414900000041851.jpg"/>
# </div>
# <strong>유니폼브릿지 20 S/S 시즌오프</strong>
# <p>유니폼브릿지의 20 S/S 시즌오프 기획전입니다. 유니폼브릿지의 20 S/S  상품과 다양한 이월 상품들을  최대 70% 할인된 가격에 만나보세요.</p>
# <span>20.07.16 - 20.07.26</span>
# </a>
# </li>
# <li>
# <a href="/app/plan/views/10639">
# <div class="img">
# <img alt="바스틱 20 S/S 시즌오프" src="//image.musinsa.com/images/plan_w_mobile_img/2020071610564700000008857.jpg"/>
# </div>
# <strong>바스틱 20 S/S 시즌오프</strong>
# <p>바스틱 20 S/S 시즌오프 기획전입니다. 무신사에서 브랜드 바스틱의 다양한 상품을 단독 최대 40% 할인된 가격에 만나 보세요.</p>
# <span>20.07.16 - 20.07.31</span>
# </a>
# </li>
# <li>
# <a href="/app/plan/views/10643">
# <div class="img">
# <img alt="간트 파이널 세일" src="//image.musinsa.com/images/plan_w_mobile_img/2020071610335400000057175.jpg"/>
# </div>
# <strong>간트 파이널 세일</strong>
# <p>간트 파이널 세일 기획전 입니다. 20 S/S 상품을 최대 50% 할인된 가격으로 만나볼 수 있습니다.</p>
# <span>20.07.16 - 20.07.30</span>
# </a>
# </li>
# <li>
# <a href="/app/plan/views/10511">
# <div class="img">
# <img alt="이 옷 활용법 특별전 : 우아" src="//image.musinsa.com/images/plan_w_mobile_img/2020071409095500000008129.jpg"/>
# </div>
# <strong>이 옷 활용법 특별전 : 우아</strong>
# <p>우신사TV 이 옷 활용법 특별전입니다. 우아의 20 S/S를  단독 최대 20% 할인된 가격으로 만나보세요.</p>
# <span>20.07.15 - 20.07.22</span>
# </a>
# </li>
# <li>
# <a href="/app/plan/views/10605">
# <div class="img">
# <img alt="나우 특별 기획전" src="//image.musinsa.com/images/plan_w_mobile_img/2020071516140400000097903.jpg"/>
# </div>
# <strong>나우 특별 기획전</strong>
# <p>나우 특별 기획전입니다. 킨포크의 고장 포클렌트에서 시작한 친환경 브랜드 나우의 다양한 상품을 지금 바로 만나보세요.</p>
# <span>20.07.15 - 20.07.29</span>
# </a>
# </li>
# </ul>
# <!-- //기획전 목록 -->
# </div>
# <!--//쇼핑기획 -->
# </div><!-- display_table_cell->
# 			<!-- //left (상품리스트,기획전) 영역 -->
# <!-- 큐레이팅 -->
# <div class="goodsCuratingArea hover_box" id="curating">
# <span class="title-box font-mss">Curating <span class="korSub">큐레이팅</span></span><span class="link_type box_all_link"><a app="" curating="" href="/app/curating/lists&lt;a href=" lists?u_cat_cd='001001"'>전체</a>"&gt;전체보기</span></div></div></input></input></input></input></input></input></input></form></div></div></body></html>
# <div class="goodsCuratingSection" id="curating_area">
# <!-- 리스트 -->
# <div class="goodsCuratingContent">
# <p class="curatingContentImg">
# <a href="/app/curating/views/17284"><img src="//image.msscdn.net/data/curating/17284/17284_1_360.jpg"/></a>
# </p>
# <h2 onclick="location.href='/app/curating/views/17284'">지구가 녹고 있어요</h2>
# <p class="curating_substance">
# 							매년 무더운 여름이 되면 “이러다 지구가 녹아 버리는 건 아닐까?”란 걱정 어린 생각이 든다. 실제로 빙하가 녹고 있으니 아예 없는 말은 아니지만, 환경을 좀 더 생각해야 할 필요가 있다는 것. 유니스디자인은 환경 문제에 대한 심각성을 티셔츠에 담았다. 건강한 지구를 위한 메시지도 함께. 소중한 지구를 좀 더 생각할 수 있는 일은 그리 어렵지 않다. / 에디터 : 김다미
# 						</p>
# </div>
# <div class="goodsCuratingProduct">
# <ul>
# <li>
# <a href="/app/product/detail/1456627/0">
# <img alt="유니스디자인(UNIIS DESIGN) 멜팅얼스 프린트티 _네이비" src="//image.msscdn.net/images/goods_img/20200521/1456627/1456627_1_50.jpg" title=""/>
# </a>
# <div class="box_info">
# <p><b>유니스디자인</b></p>
# <p>
# <span>
# <a href="/app/product/detail/1456627/0">멜팅얼스 프린트티.../UNSD</a>
# </span>
# <br/>
# <b>28,000원</b>
# <span class="img-score score_45"></span>
# <span class="curatingProductRed">24</span>
# </p>
# </div>
# </li>
# <li>
# <a href="/app/product/detail/1456614/0">
# <img alt="유니스디자인(UNIIS DESIGN) 멜팅얼스 프린트티 _네이쳐 그린" src="//image.msscdn.net/images/goods_img/20200521/1456614/1456614_1_50.jpg" title=""/>
# </a>
# <div class="box_info">
# <p><b>유니스디자인</b></p>
# <p>
# <span>
# <a href="/app/product/detail/1456614/0">멜팅얼스 프린트티 _네이쳐.../UNSD</a>
# </span>
# <br/>
# <b>28,000원</b>
# <span class="img-score score_45"></span>
# <span class="curatingProductRed">32</span>
# </p>
# </div>
# </li>
# </ul>
# </div>
# <div class="goodsCuratingContent">
# <p class="curatingContentImg">
# <a href="/app/curating/views/17283"><img src="//image.msscdn.net/data/curating/17283/17283_1_360.jpg"/></a>
# </p>
# <h2 onclick="location.href='/app/curating/views/17283'">로고의 힘</h2>
# <p class="curating_substance">
# 							강렬한 인상을 남기는 필루미네이트의 새로운 로고가 인기다. 그래피티 스타일의 로고가 담긴 티셔츠가 특히 많은 사랑을 받고 있다. 여기에 트렌디한 타이다이 컬러까지 더했으니 무슨 말을 더할까 싶다. 이건 그냥 가져야 한다. 컬러별로 모두 준비해 놓으면 이번 여름은 물론이고, 내년까지 코디 걱정하지 않고 보낼 수 있다. 이런 게 바로 새로운 로고가 가져다준 시너지 효과다. / 에디터 : 김용현
# 						</p>
# </div>
# <div class="goodsCuratingProduct">
# <ul>
# <li>
# <a href="/app/product/detail/1440594/0">
# <img alt="필루미네이트(FILLUMINATE) 유니섹스 오버핏 타이다이 콘벡스 로고 티-그린" src="//image.msscdn.net/images/goods_img/20200512/1440594/1440594_3_50.jpg" title=""/>
# </a>
# <div class="box_info">
# <p><b>필루미네이트</b></p>
# <p>
# <span>
# <a href="/app/product/detail/1440594/0">유니섹스 오버핏 타이다이 콘벡스 로고.../Unisex Overfit Tie-dye Convex Logo Tee</a>
# </span>
# <br/>
# <b>31,200원</b>
# <span class="img-score score_45"></span>
# <span class="curatingProductRed">5</span>
# </p>
# </div>
# </li>
# <li>
# <a href="/app/product/detail/1440596/0">
# <img alt="필루미네이트(FILLUMINATE) 유니섹스 오버핏 타이다이 콘벡스 로고 티-차콜" src="//image.msscdn.net/images/goods_img/20200512/1440596/1440596_2_50.jpg" title=""/>
# </a>
# <div class="box_info">
# <p><b>필루미네이트</b></p>
# <p>
# <span>
# <a href="/app/product/detail/1440596/0">유니섹스 오버핏 타이다이 콘벡스 로고.../Unisex Overfit Tie-dye Convex Logo Tee</a>
# </span>
# <br/>
# <b>31,200원</b>
# <span class="img-score score_50"></span>
# <span class="curatingProductRed">21</span>
# </p>
# </div>
# </li>
# </ul>
# </div>
# <div class="goodsCuratingContent">
# <p class="curatingContentImg">
# <a href="/app/curating/views/17278"><img src="//image.msscdn.net/data/curating/17278/17278_1_360.jpg"/></a>
# </p>
# <h2 onclick="location.href='/app/curating/views/17278'">청포도 담은 서머템</h2>
# <p class="curating_substance">
# 							센스 넘치는 디자인을 자랑하는 스테레오 바이널즈와 호가든이 만났다. 단순히 호가든이면 이렇게 소개하지 않는다. 여름과 잘 어울리는 청포도 맛을 담은 호가든 그린 그레이프라 이번 협업은 더욱 돋보인다. 상큼한 그린 컬러로 새로워진 H로고를 스테레오 바이널즈의 다양한 아이템에 담았다. 가장 먼저 눈에 띄는 것은 볼캡과 티셔츠. 여름과 잘 어울리는 로고의 컬러와 신선한 느낌의 청포도 그래픽이 찰떡이다. / 에디터 : 김용현
# 						</p>
# </div>
# <div class="goodsCuratingProduct">
# <ul>
# <li>
# <a href="/app/product/detail/1511414/0">
# <img alt="스테레오 바이널즈(STEREO VINYLS) [SS20 SV X Hoegaarden] H Logo Ballcap" src="//image.msscdn.net/images/goods_img/20200709/1511414/1511414_1_50.jpg" title=""/>
# </a>
# <div class="box_info">
# <p><b>스테레오 바이널즈</b></p>
# <p>
# <span>
# <a href="/app/product/detail/1511414/0">[SS20 SV X Hoegaarden].../SVHTAA900</a>
# </span>
# <br/>
# <b>30,400원</b>
# </p>
# </div>
# </li>
# <li>
# <a href="/app/product/detail/1511411/0">
# <img alt="스테레오 바이널즈(STEREO VINYLS) [SS20 SV X Hoegaarden] Green Grape T-Shirts" src="//image.msscdn.net/images/goods_img/20200709/1511411/1511411_1_50.jpg" title=""/>
# </a>
# <div class="box_info">
# <p><b>스테레오 바이널즈</b></p>
# <p>
# <span>
# <a href="/app/product/detail/1511411/0">[SS20 SV X Hoegaarden].../SVSTAA901</a>
# </span>
# <br/>
# <b>30,400원</b>
# </p>
# </div>
# </li>
# </ul>
# </div>
# <div class="goodsCuratingContent">
# <p class="curatingContentImg">
# <a href="/app/curating/views/17274"><img src="//image.msscdn.net/data/curating/17274/17274_1_360.jpg"/></a>
# </p>
# <h2 onclick="location.href='/app/curating/views/17274'">조용히 관심받고 싶은 날</h2>
# <p class="curating_substance">
# 							굳이 나서지 않고도 주변 시선을 사로잡을 수 있는 티셔츠가 있어. 미나브의 노이즈 빌리지 프린팅 티셔츠는 ‘노이즈’라는 단어가 들어갔지만 조용하고 담백한 매력을 가지고 있는 아이템이야. 오로지 무채색의 점과 면으로 이루어진 그래픽은 극도의 간결함이 매력. 깔끔한 핏의 청바지나 슬랙스와 함께 입어주면 주변에서 “어 저 친구 센스가 보통이 아닌데?”라고 생각할 거야! / 에디터 : 이해인
# 						</p>
# </div>
# <div class="goodsCuratingProduct">
# <ul>
# <li>
# <a href="/app/product/detail/1508075/0">
# <img alt="미나브(MINAV) 노이즈 빌리지 프린팅 티셔츠 [아이보리]" src="//image.msscdn.net/images/goods_img/20200707/1508075/1508075_1_50.jpg" title=""/>
# </a>
# <div class="box_info">
# <p><b>미나브</b></p>
# <p>
# <span>
# <a href="/app/product/detail/1508075/0">노이즈 빌리지 프린팅 티셔츠.../20ss_110</a>
# </span>
# <br/>
# <b>32,000원</b>
# </p>
# </div>
# </li>
# <li>
# <a href="/app/product/detail/1508074/0">
# <img alt="미나브(MINAV) 노이즈 빌리지 프린팅 티셔츠 [블랙]" src="//image.msscdn.net/images/goods_img/20200707/1508074/1508074_1_50.jpg" title=""/>
# </a>
# <div class="box_info">
# <p><b>미나브</b></p>
# <p>
# <span>
# <a href="/app/product/detail/1508074/0">노이즈 빌리지 프린팅 티셔츠.../20ss_109</a>
# </span>
# <br/>
# <b>32,000원</b>
# </p>
# </div>
# </li>
# </ul>
# </div>
# <!-- //리스트 -->
# </div>
# <a href="javascript:void(0)" onclick="GetMoreCurating(); return false;"><div class="moreViewBtn" id="more_btn">더보기</div></a>
#
# <!--// 큐레이팅 -->
#
#
# <!--// 컨텐츠 영역 -->
# <!-- 하단 콘텐츠 영역 -->
# <footer class="clear" id="bot">
# <div class="footer footer-musinsa">
# <div class="snb snb_store">
# <ul class="clearfix_store">
# <li class="division"><a href="https://www.musinsa.com/company/" target="_blank">회사소개</a></li>
# <li class="division"><a href="https://www.musinsa.com/?m=forum&amp;bid=event_notice">공지사항</a></li>
# <li class="division"><a href="/app/cs/notice_list">스토어공지</a></li>
# <li class="division"><a href="https://recruit.musinsa.com/">채용<span>진행중</span></a></li>
# <li class="division"><a href="/app/company/partner">입점/제휴/대량구매</a></li>
# <li class="division"><a href="https://www.musinsa.com/?mod=private"><strong>개인정보처리방침</strong></a></li>
# <li>
# <a href="https://www.musinsa.com/?mod=agreement">이용약관</a>
# </li>
# </ul>
# </div>
# <div class="row1 row">
# <div class="addressBox-wrapper clearfix">
# <div class="editing-addressBox addressBox">
# <p class="title">무신사 편집팀</p>
# <p class="address">서울특별시 강남구 신사동 640-2<br>로빈명품관 지하1층, 무신사 편집팀</br></p>
# <p class="notice">(무신사 스토어 반송지 아님, 해당주소 반송불가)</p>
# </div>
# <div class="store-addressBox addressBox">
# <p class="title">무신사 스토어</p>
# <p class="address">(17759) 경기도 평택시 신장로 55 CJ대한통운 평택합정집배점 내 무신사 물류센터</p>
# <p class="notice">(무신사 스토어 자체 배송 상품 물류센터)</p>
# <p class="notice">(배송센터 직접 물건 수령 불가)</p>
# </div>
# <div class="cs-addressBox addressBox">
# <p class="title">고객센터
# 						<span class="brackets">
# 							[ <a class="division" href="/app/cs/faq"><span>FAQ</span></a>
# <a class="division" href="/app/cs/counsel"><span>1:1질문하기</span></a>
# <a href="mailto:cs@musinsa.com"><span>이메일문의</span></a> ]
# 						</span>
# </p>
# <div class="phoneNumberBox">
# <p class="phoneNumber">
# <span class="tel_number">대표전화</span>
# <span class="number font-mss">1544-7199</span>
# <span class="phoneNumber_click"><a href="/app/cs/faq">전화문의 전 <strong>CLICK</strong></a></span>
# </p>
# <p class="description">1번 : 배송 / 교환 / 환불관련</p>
# <p class="description">2번 : 결제 / 회원 관련</p>
# <p class="subDescription">ㄴ상품 문의 &gt; 각 상품 Q&amp;A 이용</p>
# </div>
# <p class="notice">오전9시-오후6시(토,일, 공휴일 휴무)</p>
# </div>
# </div>
# <span class="global-notice store_footer_notice">각 브랜드마다 물류센터가 다릅니다. 교환/환불 시 주문 조회 메뉴를 통해 해당 제품이 출고된 곳으로 반송하셔야 합니다.</span>
# </div>
# <div class="row2 row">
# <div class="copyright-box box">
# <div class="footer_social">
# <a class="youtube" href="https://youtube.com/musinsatv" target="_blank">무신사 유튜브 채널 바로가기</a>
# <a class="instagram" href="https://instagram.com/musinsacom" target="_blank">무신사 인스타그램 바로가기</a>
# <a class="facebook" href="https://www.facebook.com/musinsa" target="_blank">무신사 페이스북 바로가기</a>
# <a class="twitter" href="https://twitter.com/musinsacom" target="_blank">무신사 트위터 바로가기</a> <a class="post" href="https://post.naver.com/musinsa_store" target="_blank">무신사 네이버 포스트 바로가기</a>
# <a class="studio" href="https://www.musinsastudio.com/" target="_blank">무신사 스튜디오 바로가기</a>
# <a class="tv" href="http://tv.musinsa.com/" target="_blank">무신사 TV 바로가기</a>
# <a class="terrace" href="https://www.musinsaterrace.com" target="_blank">무신사 테라스 바로가기</a>
# </div>
# <div class="title font-mss"><p>COPYRIGHT (C) MUSINSA ALL RIGHTS RESERVED.</p></div>
# <div class="description">
# <p>
# 					무신사닷컴 내 매거진, 스트리트스냅, 스토어 등 무신사 자체 생성 콘텐츠는 무신사닷컴 및 무신사 계약업체에 저작권이 있습니다.
# 					</p>
# <p>
# 						이러한 콘텐츠는 출처를 밝히고(무신사닷컴 표기 및 www.musinsa.com 링크 포함 필수) 비상업적인 용도에서만 활용하실 수 있습니다.
# 					<a href="https://www.musinsa.com/?m=forum&amp;bid=event_notice&amp;p=3&amp;mod=view&amp;uid=15974">자세히보기</a>
# </p>
# <p class="last">
# 						커뮤니티 및 중고장터, 댓글 등 무신사 회원이 올린 이미지가 저작권에 위배될 경우
# 						<a href="javascript:void(0)" onclick="javascript:window.open('https://www.musinsa.com/?m=bbs&amp;bid=suggest','','left=0,top=0,width=600px,height=700px,statusbar=no,scrollbars=yes,toolbar=no');">신고</a>
# 						하시면 검토 후 삭제하겠습니다.
# 					</p>
# </div>
# </div>
# <div class="authentication-box box clearfix">
# <p class="authentication font-mss">100% AUTHENTIC</p>
# <p class="description">무신사스토어에서 판매되는 모든 브랜드 제품은 정식제조, 정식수입원을 통해 유통되는 100% 정품임을 보증합니다.</p>
# <p class="address">주식회사 무신사 (MUSINSA Co., Ltd.) | 서울특별시 강남구 신사동 640-2 로빈명품관 지하1층 | 사업자등록번호 : 211-88-79575 |<br/>통신판매업 : 2012-서울강남-01897 | 대표 : 조만호 | 개인정보관리책임자 : 이진우(<a href="mailto:help@musinsa.com">help@musinsa.com</a>) ｜ 호스팅사업자 : 아마존웹서비스(Amazon Web Services)</p>
# <div class="imageBox">
# <a href="javascript:void(0)" onclick="window.open('http://admin.kcp.co.kr/Modules/escrow/kcp_pop.jsp?site_cd=N5624','escro','top=10.left=10,width=500,height=450')"><img alt="kcp에스크로확인" src="//image.msscdn.net/skin/musinsa/images/footer/escrow.gif"/></a>
# <a href="javascript:void(0)" onclick="window.open('http://www.ftc.go.kr/info/bizinfo/communicationViewPopup.jsp?wrkr_no=2118879575','communicationViewPopup','top=10.left=10,width=750,height=700')"><img alt="사업자정보확인" class="last" src="//image.msscdn.net/skin/musinsa/images/footer/ftc.gif"/></a>
# </div>
# </div>
# </div>
# <div class="row3 row">
# <p class="title font-mss">FASHION WEB MAGAZINE / LIFE STYLE SELECT SHOP <span>WWW.MUSINSA.COM</span></p>
# </div>
# </div>
# </footer>
# <!-- 랜덤 이벤트 팝업 -->
# <!-- //랜덤 이벤트 팝업 -->
# <div class="ui-layer-close fixed"></div>
# <meta content="NqB0BDAEWJTvAPCCxzrckJYnS7-xJILFU40FvSmh5S8" name="google-site-verification">
# <script async="true" src="//static.msscdn.net/skin/musinsa/js/jquery.url.packed.js?20160119" type="text/javascript"></script> <!--// 하단 콘텐츠 영역 -->
# </meta>
# <!--// 오른쪽 콘텐츠 영역 -->
#
# <!--// wrap -->

# %%
# id로 찾는 것이 베스트이다.
li_box = soup.find('ul',id='searchList').find_all('li',class_='li_box')
len(li_box)
# Out:
# 90

# %%
li_box[0]
# Out:
# <li class="li_box">
# <!--icon-->
# <div class="icon_new">NEW</div>
# <!--//icon-->
# <!--group-->
# <div class="icon_group">
# <ul>
# <li class="icon_man sight_out" title="남성">남성</li>
# </ul>
# </div>
# <!--//group-->
# <div class="li_inner">
# <!--image-->
# <div class="list_img">
# <a class="img-block" href="/app/product/detail/1517122/0">
# <img alt="그레이버(GRAVER) [UNISEX]도트보드 자수 화이트클립 반팔티_2color" class="lazyload lazy" data-original="//image.msscdn.net/images/goods_img/20200716/1517122/1517122_1_125.jpg" src="//image.msscdn.net/0.gif" title="">
# </img></a>
# </div>
# <!--//image-->
# <!--info-->
# <div class="article_info">
# <p class="item_title"><a href="/app/brand/goods_list/graver">그레이버</a></p>
# <p class="list_info">
# <a href="/app/product/detail/1517122/0" title="[UNISEX]도트보드 자수 화이트클립 반팔티_2color">
# 				[UNISEX]도트보드 자수 화이트클립 반팔티_2color</a>
# </p>
# <p class="price">
# 								42,000원
# 			</p>
# <p class="membership" onclick="viewMemberPrice2('sPrice_1517122', '1517122', '0');">MEMBERSHIP PRICE<span class="fr">▼</span></p>
# <div class="member_price" id="sPrice_1517122" style="display:none; z-index: 9999;">
# <p>무신사 회원가<span class="fr"><a href="javascript:void(0);return false;" onclick="viewMemberPrice2('sPrice_1517122', '1517122', '0');">X</a></span></p>
# <ul>
# <li class="pertinent" style="border-bottom:1px solid #ddd;"><span>&gt;</span>
# 						비회원<span class="txt_price_member">42,000원</span>
# </li>
# </ul>
# </div>
# <p class="point"><!--P 0 /  -->
# </p>
# </div>
# </div>
# <!--//info-->
# <!--option-->
# <div class="option">
# <p class="option_btn">
# <a href="#pol1517122" onclick="viewOption3(this, '1517122', '0'); return false;">OPTION ▼</a>
# </p>
# <div class="list_pol_goods" id="pol1517122" style="display:none;"></div>
# </div>
# <!--//option-->
# </li>

# %%
brand = li_box[0].find
